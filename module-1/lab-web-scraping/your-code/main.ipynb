# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
from urllib.request import urlopen
import random
import re
# import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
#your code
github_html = requests.get(url).text
soup = BeautifulSoup(github_html, "html.parser")
#print(soup)

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
#your code
#h2 = soup.find_all('h2')
#developers = []
#for a in h2:
#    parte1 = a.find_all('a')
#    for dev in parte1:
#        parte2 = dev.find_all('span')
#        nick = dev.text.strip().replace('\n', '')
#        nick = nick.split()
#        if parte2:
#            for empresa in parte2:
#                temp = empresa.text.strip().replace('\n', '')
#                developers.append(nick[0] + ' ' + temp)
#        else:
#            developers.append(nick[0])
        
#developers

def elimina(t):
    t = re.sub(' ','',t)
    t = re.sub('\n\n',' ',t)
    return t.strip()

dev2 = [d.text for d in soup.find_all('h2')]
dev2 = list(map(elimina, dev2))

dev2
# Out:
# ['jackfrued (骆昊)',
#  'facebook (Facebook)',
#  'robb0wen (RobbOwen)',
#  'TheAlgorithms (TheAlgorithms)',
#  'Microsoft (Microsoft)',
#  'azl397985856 (lucifer)',
#  'abhat222 (AsifBhat)',
#  'pytorch',
#  'HFO4 (AaronLiu)',
#  'symfony (Symfony)',
#  'google (Google)',
#  '996icu',
#  'MisterBooo (程序员吴师兄)',
#  'vadimdemedes (VadimDemedes)',
#  'czy36mengfei',
#  'apache (TheApacheSoftwareFoundation)',
#  'sindresorhus (SindreSorhus)',
#  'agentofuser (AgentofUser)',
#  'Sua-Park',
#  'sveltejs (Svelte)',
#  'tensorflow',
#  'S-March',
#  'jaywcjlove (小弟调调™)',
#  'Novvum (Novvum)',
#  'vuejs (vuejs)',
#  'Product',
#  'Platform',
#  'Support',
#  'Company']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
#your code

github_html_py = requests.get(url).text
soup_py = BeautifulSoup(github_html_py, "html.parser")

# %%
#h3 = soup_py.find_all('h3')
#repository = []
#for a in h3:
#    parte1 = a.find_all('a')
#    for fila in parte1:
#        repo = fila.text.strip().replace('\n', '').replace('/', '')
#        repository.append(repo)      
#repository

def elimina_p(t):
    t = re.sub(' ','',t)
    t = re.sub('\n','',t)
    t = re.sub('/',' - ',t)
    return t

repository = [r.text for r in soup_py.find_all('h3')]
repository = list(map(elimina_p, repository))
repository
# Out:
# ['jackfrued - Python-100-Days',
#  'TheAlgorithms - Python',
#  'pytorch - botorch',
#  'cool-RR - PySnooper',
#  'Helpsypoo - primer',
#  'ColCarroll - ridge_map',
#  'vulmon - Vulmap',
#  'vinta - awesome-python',
#  'donnemartin - system-design-primer',
#  'tensorflow - models',
#  'cknd - stackprinter',
#  'D4stiny - Dell-Support-Assist-RCE-PoC',
#  'apachecn - AiLearning',
#  'home-assistant - home-assistant',
#  'benedekrozemberczki - graph2vec',
#  'toddmotto - public-apis',
#  'PengBoXiangShang - SiamRPN_plus_plus_PyTorch',
#  'jayshah19949596 - CodingInterviews',
#  'OWASP - CheatSheetSeries',
#  'twintproject - twint',
#  '3b1b - manim',
#  'ytdl-org - youtube-dl',
#  'KakaoBrain - fast-autoaugment',
#  'ageitgey - face_recognition',
#  'pallets - flask']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
#your code

disney_html = requests.get(url).text
soup_disney = BeautifulSoup(disney_html, "html.parser")

# %%
enlaces = soup_disney.find_all('img')
images_src = [img['src'].replace('//', '') for img in soup_disney.findAll('img')]
images_src
# Out:
# ['upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png',
#  'upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png',
#  'upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  'upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  'upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Newman_Laugh-O-Gram_%281921%29.webm/220px-seek%3D2-Newman_Laugh-O-Gram_%281921%29.webm.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/7/71/Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg/170px-Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg',
#  'upload.wikimedia.org/wikipedia/en/thumb/4/4e/Steamboat-willie.jpg/170px-Steamboat-willie.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/5/57/Walt_Disney_1935.jpg/170px-Walt_Disney_1935.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Walt_Disney_Snow_white_1937_trailer_screenshot_%2813%29.jpg/220px-Walt_Disney_Snow_white_1937_trailer_screenshot_%2813%29.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/1/15/Disney_drawing_goofy.jpg/170px-Disney_drawing_goofy.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/1/13/DisneySchiphol1951.jpg/220px-DisneySchiphol1951.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/8/8c/WaltDisneyplansDisneylandDec1954.jpg/220px-WaltDisneyplansDisneylandDec1954.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Walt_disney_portrait_right.jpg/170px-Walt_disney_portrait_right.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Walt_Disney_Grave.JPG/170px-Walt_Disney_Grave.JPG',
#  'upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Roy_O._Disney_with_Company_at_Press_Conference.jpg/170px-Roy_O._Disney_with_Company_at_Press_Conference.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/a/a9/Disney_Display_Case.JPG/170px-Disney_Display_Case.JPG',
#  'upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Disney1968.jpg/170px-Disney1968.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png',
#  'upload.wikimedia.org/wikipedia/en/thumb/6/69/P_vip.svg/29px-P_vip.svg.png',
#  'upload.wikimedia.org/wikipedia/en/thumb/e/e7/Video-x-generic.svg/30px-Video-x-generic.svg.png',
#  'upload.wikimedia.org/wikipedia/commons/thumb/a/a3/Flag_of_Los_Angeles_County%2C_California.svg/30px-Flag_of_Los_Angeles_County%2C_California.svg.png',
#  'upload.wikimedia.org/wikipedia/commons/thumb/a/a3/USA_flag_on_television.svg/30px-USA_flag_on_television.svg.png',
#  'upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/22px-Commons-logo.svg.png',
#  'upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikiquote-logo.svg/25px-Wikiquote-logo.svg.png',
#  'upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/30px-Wikidata-logo.svg.png',
#  'upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png',
#  'en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1',
#  '/static/images/wikimedia-button.png',
#  '/static/images/poweredby_mediawiki_88x31.png']

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
#your code
python_html = requests.get(url).text
soup_py = BeautifulSoup(python_html, "html.parser")

# %%
enlaces_url = [a.get('href') for a in soup_py.find_all('a')]
enlaces_url
# Out:
# [None,
#  '#mw-head',
#  '#p-search',
#  'https://en.wiktionary.org/wiki/Python',
#  'https://en.wiktionary.org/wiki/python',
#  '#Snakes',
#  '#Ancient_Greece',
#  '#Media_and_entertainment',
#  '#Computing',
#  '#Engineering',
#  '#Roller_coasters',
#  '#Vehicles',
#  '#Weaponry',
#  '#People',
#  '#Other_uses',
#  '#See_also',
#  '/w/index.php?title=Python&action=edit&section=1',
#  '/wiki/Pythonidae',
#  '/wiki/Python_(genus)',
#  '/w/index.php?title=Python&action=edit&section=2',
#  '/wiki/Python_(mythology)',
#  '/wiki/Python_of_Aenus',
#  '/wiki/Python_(painter)',
#  '/wiki/Python_of_Byzantium',
#  '/wiki/Python_of_Catana',
#  '/w/index.php?title=Python&action=edit&section=3',
#  '/wiki/Python_(film)',
#  '/wiki/Pythons_2',
#  '/wiki/Monty_Python',
#  '/wiki/Python_(Monty)_Pictures',
#  '/w/index.php?title=Python&action=edit&section=4',
#  '/wiki/Python_(programming_language)',
#  '/wiki/CPython',
#  '/wiki/CMU_Common_Lisp',
#  '/wiki/PERQ#PERQ_3',
#  '/w/index.php?title=Python&action=edit&section=5',
#  '/w/index.php?title=Python&action=edit&section=6',
#  '/wiki/Python_(Busch_Gardens_Tampa_Bay)',
#  '/wiki/Python_(Coney_Island,_Cincinnati,_Ohio)',
#  '/wiki/Python_(Efteling)',
#  '/w/index.php?title=Python&action=edit&section=7',
#  '/wiki/Python_(automobile_maker)',
#  '/wiki/Python_(Ford_prototype)',
#  '/w/index.php?title=Python&action=edit&section=8',
#  '/wiki/Colt_Python',
#  '/wiki/Python_(missile)',
#  '/wiki/Python_(nuclear_primary)',
#  '/w/index.php?title=Python&action=edit&section=9',
#  '/wiki/Python_Anghelo',
#  '/w/index.php?title=Python&action=edit&section=10',
#  '/wiki/PYTHON',
#  '/w/index.php?title=Python&action=edit&section=11',
#  '/wiki/Cython',
#  '/wiki/Pyton',
#  '/wiki/File:Disambig_gray.svg',
#  '/wiki/Help:Disambiguation',
#  '//en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Python&namespace=0',
#  'https://en.wikipedia.org/w/index.php?title=Python&oldid=893749572',
#  '/wiki/Help:Category',
#  '/wiki/Category:Disambiguation_pages',
#  '/wiki/Category:Disambiguation_pages_with_short_description',
#  '/wiki/Category:All_article_disambiguation_pages',
#  '/wiki/Category:All_disambiguation_pages',
#  '/wiki/Category:Animal_common_name_disambiguation_pages',
#  '/wiki/Special:MyTalk',
#  '/wiki/Special:MyContributions',
#  '/w/index.php?title=Special:CreateAccount&returnto=Python',
#  '/w/index.php?title=Special:UserLogin&returnto=Python',
#  '/wiki/Python',
#  '/wiki/Talk:Python',
#  '/wiki/Python',
#  '/w/index.php?title=Python&action=edit',
#  '/w/index.php?title=Python&action=history',
#  '/wiki/Main_Page',
#  '/wiki/Main_Page',
#  '/wiki/Portal:Contents',
#  '/wiki/Portal:Featured_content',
#  '/wiki/Portal:Current_events',
#  '/wiki/Special:Random',
#  'https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en',
#  '//shop.wikimedia.org',
#  '/wiki/Help:Contents',
#  '/wiki/Wikipedia:About',
#  '/wiki/Wikipedia:Community_portal',
#  '/wiki/Special:RecentChanges',
#  '//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  '/wiki/Special:WhatLinksHere/Python',
#  '/wiki/Special:RecentChangesLinked/Python',
#  '/wiki/Wikipedia:File_Upload_Wizard',
#  '/wiki/Special:SpecialPages',
#  '/w/index.php?title=Python&oldid=893749572',
#  '/w/index.php?title=Python&action=info',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q747452',
#  '/w/index.php?title=Special:CiteThisPage&page=Python&id=893749572',
#  '/w/index.php?title=Special:Book&bookcmd=book_creator&referer=Python',
#  '/w/index.php?title=Special:ElectronPdf&page=Python&action=show-download-screen',
#  '/w/index.php?title=Python&printable=yes',
#  'https://commons.wikimedia.org/wiki/Category:Python',
#  'https://af.wikipedia.org/wiki/Python',
#  'https://als.wikipedia.org/wiki/Python',
#  'https://az.wikipedia.org/wiki/Python',
#  'https://bn.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8_(%E0%A6%A6%E0%A7%8D%E0%A6%AC%E0%A7%8D%E0%A6%AF%E0%A6%B0%E0%A7%8D%E0%A6%A5%E0%A6%A4%E0%A6%BE_%E0%A6%A8%E0%A6%BF%E0%A6%B0%E0%A6%B8%E0%A6%A8)',
#  'https://be.wikipedia.org/wiki/Python',
#  'https://bg.wikipedia.org/wiki/%D0%9F%D0%B8%D1%82%D0%BE%D0%BD_(%D0%BF%D0%BE%D1%8F%D1%81%D0%BD%D0%B5%D0%BD%D0%B8%D0%B5)',
#  'https://cs.wikipedia.org/wiki/Python_(rozcestn%C3%ADk)',
#  'https://da.wikipedia.org/wiki/Python',
#  'https://de.wikipedia.org/wiki/Python',
#  'https://eo.wikipedia.org/wiki/Pitono_(apartigilo)',
#  'https://eu.wikipedia.org/wiki/Python_(argipena)',
#  'https://fa.wikipedia.org/wiki/%D9%BE%D8%A7%DB%8C%D8%AA%D9%88%D9%86',
#  'https://fr.wikipedia.org/wiki/Python',
#  'https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%84%A0',
#  'https://hr.wikipedia.org/wiki/Python_(razdvojba)',
#  'https://io.wikipedia.org/wiki/Pitono',
#  'https://id.wikipedia.org/wiki/Python',
#  'https://ia.wikipedia.org/wiki/Python_(disambiguation)',
#  'https://is.wikipedia.org/wiki/Python_(a%C3%B0greining)',
#  'https://it.wikipedia.org/wiki/Python_(disambigua)',
#  'https://he.wikipedia.org/wiki/%D7%A4%D7%99%D7%AA%D7%95%D7%9F',
#  'https://ka.wikipedia.org/wiki/%E1%83%9E%E1%83%98%E1%83%97%E1%83%9D%E1%83%9C%E1%83%98_(%E1%83%9B%E1%83%A0%E1%83%90%E1%83%95%E1%83%90%E1%83%9A%E1%83%9B%E1%83%9C%E1%83%98%E1%83%A8%E1%83%95%E1%83%9C%E1%83%94%E1%83%9A%E1%83%9D%E1%83%95%E1%83%90%E1%83%9C%E1%83%98)',
#  'https://kg.wikipedia.org/wiki/Mboma_(nyoka)',
#  'https://la.wikipedia.org/wiki/Python_(discretiva)',
#  'https://lb.wikipedia.org/wiki/Python',
#  'https://hu.wikipedia.org/wiki/Python_(egy%C3%A9rtelm%C5%B1s%C3%ADt%C5%91_lap)',
#  'https://mr.wikipedia.org/wiki/%E0%A4%AA%E0%A4%BE%E0%A4%AF%E0%A4%A5%E0%A5%89%E0%A4%A8_(%E0%A4%86%E0%A4%9C%E0%A5%8D%E0%A4%9E%E0%A4%BE%E0%A4%B5%E0%A4%B2%E0%A5%80_%E0%A4%AD%E0%A4%BE%E0%A4%B7%E0%A4%BE)',
#  'https://nl.wikipedia.org/wiki/Python',
#  'https://ja.wikipedia.org/wiki/%E3%83%91%E3%82%A4%E3%82%BD%E3%83%B3',
#  'https://no.wikipedia.org/wiki/Pyton',
#  'https://pl.wikipedia.org/wiki/Pyton',
#  'https://pt.wikipedia.org/wiki/Python_(desambigua%C3%A7%C3%A3o)',
#  'https://ru.wikipedia.org/wiki/Python_(%D0%B7%D0%BD%D0%B0%D1%87%D0%B5%D0%BD%D0%B8%D1%8F)',
#  'https://sd.wikipedia.org/wiki/%D8%A7%D8%B1%DA%99',
#  'https://sk.wikipedia.org/wiki/Python',
#  'https://sh.wikipedia.org/wiki/Python',
#  'https://fi.wikipedia.org/wiki/Python',
#  'https://sv.wikipedia.org/wiki/Pyton',
#  'https://th.wikipedia.org/wiki/%E0%B9%84%E0%B8%9E%E0%B8%97%E0%B8%AD%E0%B8%99',
#  'https://tr.wikipedia.org/wiki/Python',
#  'https://uk.wikipedia.org/wiki/%D0%9F%D1%96%D1%84%D0%BE%D0%BD',
#  'https://ur.wikipedia.org/wiki/%D9%BE%D8%A7%D8%A6%DB%8C%D8%AA%DA%BE%D9%88%D9%86',
#  'https://vi.wikipedia.org/wiki/Python',
#  'https://zh.wikipedia.org/wiki/Python_(%E6%B6%88%E6%AD%A7%E4%B9%89)',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q747452#sitelinks-wikipedia',
#  '//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#  '//creativecommons.org/licenses/by-sa/3.0/',
#  '//foundation.wikimedia.org/wiki/Terms_of_Use',
#  '//foundation.wikimedia.org/wiki/Privacy_policy',
#  '//www.wikimediafoundation.org/',
#  'https://foundation.wikimedia.org/wiki/Privacy_policy',
#  '/wiki/Wikipedia:About',
#  '/wiki/Wikipedia:General_disclaimer',
#  '//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  'https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute',
#  'https://foundation.wikimedia.org/wiki/Cookie_statement',
#  '//en.m.wikipedia.org/w/index.php?title=Python&mobileaction=toggle_view_mobile',
#  'https://wikimediafoundation.org/',
#  '//www.mediawiki.org/']

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
#your code
titles_html = requests.get(url).text
soup_title = BeautifulSoup(titles_html, "html.parser")

# %%
titles = [t.text.strip().replace('\n', '') for t in soup_title.find_all('div', class_= 'usctitlechanged')]
print(len(titles))
titles
# Out:
# 1
# ['Title 42 - The Public Health and Welfare']

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
#your code 
fbi_html = requests.get(url).text
soup_fbi = BeautifulSoup(fbi_html, "html.parser")

# %%
buscados = [f.text.strip().replace('\n', '') for f in soup_fbi.find_all('h3', class_= 'title')]
buscados
# Out:
# ['ALEJANDRO ROSALES CASTILLO',
#  'YASER ABDEL SAID',
#  'JASON DEREK BROWN',
#  'RAFAEL CARO-QUINTERO',
#  'ALEXIS FLORES',
#  'SANTIAGO VILLALBA MEDEROS',
#  'ROBERT WILLIAM FISHER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'LAMONT STEPHENSON',
#  'GREG ALYN CARLSON']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
#your code
ea_html = requests.get(url).text
soup_ea = BeautifulSoup(ea_html, "html.parser")

# %%
data = []
table = soup_ea.find_all('tr', class_= 'normal')

for td in table:
    #print(td)
    temp_fecha = td.contents[3].find('a').text
    temp_fecha = temp_fecha.split()
    fecha = temp_fecha[0]
    hora = temp_fecha[1]
    
    latitud = td.contents[4].text + td.contents[5].text
    longitud = td.contents[6].text + td.contents[7].text
    region = td.contents[11].text
    
    data.append([fecha, hora, latitud, longitud, region])

terremotos = pd.DataFrame(data, columns = ['date', 'time', 'latitude', 'longitude','region'])
terremotos.head(20)
# Out:
#           date        time   latitude   longitude  \
# 0   2019-05-02  18:56:48.0   6.67 S    127.24 E
# 1   2019-05-02  18:48:50.0  29.92 S     71.38 W
# 2   2019-05-02  18:24:23.0   2.20 N    127.11 E
# 3   2019-05-02  18:20:26.3  19.06 N     67.76 W
# 4   2019-05-02  17:13:53.6  35.33 N    118.54 W
# 5   2019-05-02  17:13:22.7  21.32 S     70.71 W
# 6   2019-05-02  16:55:54.4  37.42 N     72.18 E
# 7   2019-05-02  16:53:24.2   6.35 S    127.78 E
# 8   2019-05-02  16:38:25.0  26.02 S     70.67 W
# 9   2019-05-02  16:21:51.6  39.55 N    118.01 W
# 10  2019-05-02  16:19:42.3  63.00 N    150.80 W
# 11  2019-05-02  16:03:40.3  36.40 N     35.58 E
# 12  2019-05-02  16:01:44.0  30.84 S     71.60 W
# 13  2019-05-02  15:52:30.0   9.23 N     82.54 W
# 14  2019-05-02  15:39:28.7  29.88 N     50.86 E
# 15  2019-05-02  15:10:02.5  37.61 N     20.68 E
# 16  2019-05-02  15:04:13.3  38.48 N     39.28 E
# 17  2019-05-02  15:01:30.0   9.33 N     83.79 W
# 18  2019-05-02  14:58:28.0   1.83 S    122.50 E
# 19  2019-05-02  14:55:00.0  15.91 N     95.15 W
#
#                               region
# 0                          BANDA SEA
# 1           OFFSHORE COQUIMBO, CHILE
# 2                        MOLUCCA SEA
# 3          DOMINICAN REPUBLIC REGION
# 4                 CENTRAL CALIFORNIA
# 5        OFFSHORE ANTOFAGASTA, CHILE
# 6                         TAJIKISTAN
# 7                          BANDA SEA
# 8        OFFSHORE ANTOFAGASTA, CHILE
# 9                             NEVADA
# 10                    CENTRAL ALASKA
# 11                    CENTRAL TURKEY
# 12                   COQUIMBO, CHILE
# 13   PANAMA-COSTA RICA BORDER REGION
# 14                     SOUTHERN IRAN
# 15                        IONIAN SEA
# 16                    EASTERN TURKEY
# 17                        COSTA RICA
# 18               SULAWESI, INDONESIA
# 19           OFFSHORE OAXACA, MEXICO

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/hackathons'
url_hack = 'https://hackevents.co/search/anything/anywhere/anytime'

# %%
#your code
hack_html = requests.get(url_hack).text
soup_hack = BeautifulSoup(hack_html, "html.parser")

# %%
data_hack = []
hack = soup_hack.find_all('div', class_= 'card-body')

for temp in hack:
    titulo = temp.find('h3').text
    
    parrafos = temp.find_all('p')
    lugar = parrafos[0].text.split(',')
    ciudad = lugar[0]
    pais = lugar[1]
    
    fecha_ini = parrafos[1].text.replace('Starts', '').strip()
    fecha_fin = parrafos[2].text.replace('Ends', '').strip()
    fechas = 'Del {} al {}'.format(fecha_ini, fecha_fin)
    
    data_hack.append([fechas, titulo, ciudad, pais])

hackathon = pd.DataFrame(data_hack, columns = ['date', 'title', 'city', 'country'])
display(hackathon)
# Out:
#                           date  \
# 0   Del 5/10/2019 al 5/12/2019
# 1   Del 5/11/2019 al 5/12/2019
# 2   Del 5/13/2019 al 5/15/2019
# 3   Del 2/21/2019 al 5/17/2019
# 4   Del 5/17/2019 al 5/18/2019
# 5   Del 5/17/2019 al 5/19/2019
# 6   Del 5/18/2019 al 5/19/2019
# 7   Del 5/16/2019 al 5/19/2019
# 8   Del 5/17/2019 al 5/19/2019
# 9   Del 5/18/2019 al 5/20/2019
# 10   Del 5/31/2019 al 6/2/2019
# 11  Del 6/13/2019 al 6/13/2019
# 12  Del 6/27/2019 al 6/28/2019
# 13  Del 1/31/2019 al 9/30/2019
#
#                                                 title             city  \
# 0                  I-COM Data Science Hackathons 2019           Malaga
# 1                                           Hacktival        Karlsruhe
# 2                Bosch ConnectedExperience (BCX) 2019           Berlin
# 3        Canon Developer Community Virtual Hackathan           Online
# 4                                    HACK AND HARVEST         Konstanz
# 5                          Open Source ERPS Hackathon         Brooklyn
# 6             Global Hackathon Series - San Francisco    San Francisco
# 7   WTF IS INFRAHACK? A HACKATHON IN 3 CITIES OVER...           London
# 8                                Hacking[Engineering]           Berlin
# 9                         HackHPI about://social.good          Potsdam
# 10                                      #apoHackathon       Düsseldorf
# 11                                   EU Datathon 2019         Brussels
# 12                                     OSNA HACK 2019        Osnabrück
# 13                            Galileo App Competition           Prague
#
#             country
# 0             Spain
# 1           Germany
# 2           Germany
# 3     United States
# 4           Germany
# 5     United States
# 6     United States
# 7    United Kingdom
# 8           Germany
# 9           Germany
# 10          Germany
# 11          Belgium
# 12          Germany
# 13   Czech Republic

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/europapress'

# %%
#your code
try:
    twitter_html = requests.get(url).text
    soup_twitter = BeautifulSoup(twitter_html, "html.parser")
    tweets = [e.text.strip() for e in soup_twitter.find_all('span', class_= 'ProfileNav-value')]
    
    print(tweets[0].replace('\xa0', ' '))
    
except Exception as e:
    print('Error: ' + str(e))
# Out:
# 338 mil

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/europapress'

# %%
#your code
try:
    twitter_html = requests.get(url).text
    soup_twitter = BeautifulSoup(twitter_html, "html.parser")
    tweets = [e.text.strip() for e in soup_twitter.find_all('span', class_= 'ProfileNav-value')]
    
    print(tweets[2].replace('\xa0', ' '))
    
except Exception as e:
    print('Error: ' + str(e))
# Out:
# 1,14 M

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
#your code
wiki_html = urlopen(url)
#wiki_html = requests.get(url).text
soup_wiki = BeautifulSoup(wiki_html, "html.parser")

# %%
contenido = soup_wiki.find_all('div', class_= 'central-featured')

idioma = contenido[0].find_all('strong')
articulos = contenido[0].find_all('bdi')

idi_art = []
for i in (range(len(idioma))):
    idi = idioma[i].text
    art = re.sub('\xa0', '', articulos[i].text )
    art = re.sub('[^0-9]+','', art)
    idi_art.append( [idi, art] )
                
idi_art
# Out:
# [['English', '5844000'],
#  ['Español', '1517000'],
#  ['日本語', '1147000'],
#  ['Deutsch', '2293000'],
#  ['Русский', '1540000'],
#  ['Français', '2099000'],
#  ['Italiano', '1522000'],
#  ['中文', '1050000'],
#  ['Português', '1002000'],
#  ['Polski', '1331000']]

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
#your code
gov_html = requests.get(url).text
soup_gov = BeautifulSoup(gov_html, "html.parser")

# %%
datos_tipo = [tipo.text for tipo in soup_gov.find_all('h2')]
datos_tipo
# Out:
# ['Business and economy',
#  'Crime and justice',
#  'Defence',
#  'Education',
#  'Environment',
#  'Government',
#  'Government spending',
#  'Health',
#  'Mapping',
#  'Society',
#  'Towns and cities',
#  'Transport']

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your code
widi_html = requests.get(url).text
soup_widi = BeautifulSoup(widi_html, "html.parser")

# %%
data = []
table = soup_widi.find_all('table', class_= 'wikitable')

table_idi = [idioma.text for idioma in table[1].find_all('a') if len(idioma.text) > 3]
    
idiomas_num = pd.DataFrame(table_idi, columns = ['Idioma'])
display(idiomas_num[:10])
# Out:
#        Idioma
# 0    Mandarin
# 1     Spanish
# 2     English
# 3       Hindi
# 4      Arabic
# 5  Portuguese
# 6     Bengali
# 7     Russian
# 8    Japanese
# 9     Punjabi

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/europapress'

# %%
# your code
try:
    tweets_list = []
    twitter_html = requests.get(url).text
    soup_tweets = BeautifulSoup(twitter_html, "html.parser")
    tweets = soup_tweets.find_all('div', class_='content')
    #tweets = [e.text.strip() for e in soup_twitter.find_all('span', class_= 'ProfileNav-value')]
    #print(len(tweets))
    #t = tweets[0].find_all('p')
    #print(t[0].text)
    
    for subt in tweets:
        parrafo = subt.find_all('p')
        for t in parrafo:
            tweets_list.append(t.text.replace('\n', ' '))
        #print(tweet.find_all('div', class_='tweet-text'))
        #print(tweet.find_all('h2'))
       
    #print(tweets[0].replace('\xa0', ' '))
    display(tweets_list[:5])
except Exception as e:
    print('Error: ' + str(e))
# Out:
# ['Los embalses rozan el 60% del total tras las últimas lluvias pero tienen un 15,67% menos agua que hace un año https://www.europapress.es/sociedad/medio-ambiente-00647/noticia-embalses-rozan-60-total-ultimas-lluvias-tienen-1567-menos-agua-hace-ano-20190430125102.html\xa0…pic.twitter.com/5US64Pj2jy',
#  '#LoMásLeído | Susana Díaz: "Si Casado cree que Vox es de extrema derecha mucho está tardando en romper con ellos en Andalucía"https://www.europapress.es/andalucia/malaga-00356/noticia-diaz-si-verdad-cree-casado-vox-extrema-derecha-mucho-tardando-romper-ellos-andalucia-20190501142633.html\xa0…',
#  'El extenso patrimonio cultural de Siria está destrozado o gravemente dañado tras años de guerra que han alcanzado lugares emblemáticos como Alepo o Palmira y cuya reconstrucción a fondo no comenzará hasta que acabe el conflicto http://bit.ly/2UYLadr\xa0pic.twitter.com/mhuTrrQeag',
#  'En un pueblo de Montenegro, un centenario árbol lleva 25 años actuando como fuente de agua cuando llueve mucho y esta es su explicaciónhttps://www.europapress.es/desconecta/curiosity/noticia-hay-arbol-montenegro-brota-fuente-agua-explicacion-20190320162308.html\xa0…',
#  '#LoMásLeído | Facebook podría convertirse en un cementerio digital a finales de siglo, cuando se estima que haya unos 4.900 millones de perfiles de usuarios fallecidoshttps://www.europapress.es/portaltic/socialmedia/noticia-facebook-corre-riesgo-convertirse-cementerio-digital-finales-siglo-20190501105123.html\xa0…']

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code
lista_pelis = []
imdb_html = requests.get(url).text
soup_imdb = BeautifulSoup(imdb_html, "html.parser")

pelis = soup_imdb.find_all('td', class_='titleColumn')
pelis1 = soup_imdb.find_all('tr')

# %%
def limpia_txt(t):
    t = re.sub('[^0-9]+', '', t)
    return t

def limpia_ratio(t):
    t = re.sub('([^0-9])', '', t)
    return t[:1]+'.'+t[1:2] #esto hay que cambiarlo

res = []
res_rate = []
for td in pelis1:
    anyo = td.find('span', class_='secondaryInfo')
    res.append(str(anyo))
    rate = td.find('strong')
    res_rate.append(str(rate))



fechas = list(map(limpia_txt, res))
ratios = list(map(limpia_ratio, res_rate))
df_fecha = pd.DataFrame(fechas[1:], columns = ['Initial release'])
df_ratio = pd.DataFrame(ratios[1:], columns = ['Starts'])

# %%
for p in pelis:
    
    anyo = p.find('secondaryInfo')
    temp_tit = p.find('a')
    titulo = temp_tit.text

    if 'title' in temp_tit.attrs:
        director = temp_tit['title'].split(',')[0]

    lista_pelis.append([titulo, director])
    
lista_pelis


peliculas = pd.DataFrame(lista_pelis, columns = ['Movie','Director'])
peliculas['Initial release'] = df_fecha
peliculas['Starts'] = df_ratio
peliculas.head(250)
# Out:
#                                                  Movie  \
# 0                                      Cadena perpetua
# 1                                           El padrino
# 2                                 El padrino: Parte II
# 3                                  El caballero oscuro
# 4                                12 hombres sin piedad
# 5                                La lista de Schindler
# 6          El señor de los anillos: El retorno del rey
# 7                                         Pulp Fiction
# 8                                  Vengadores: Endgame
# 9                           El bueno, el feo y el malo
# 10                                 El club de la lucha
# 11    El señor de los anillos: La comunidad del anillo
# 12                                        Forrest Gump
# 13                              El imperio contraataca
# 14                                              Origen
# 15             El señor de los anillos: Las dos torres
# 16                 Alguien voló sobre el nido del cuco
# 17                                 Uno de los nuestros
# 18                                              Matrix
# 19                                  Los siete samuráis
# 20                                               Seven
# 21                                      Ciudad de Dios
# 22                           La guerra de las galaxias
# 23                         El silencio de los corderos
# 24                                ¡Qué bello es vivir!
# 25                                    La vida es bella
# 26                                 El viaje de Chihiro
# 27                              Salvar al soldado Ryan
# 28                              Sospechosos habituales
# 29                               El profesional (Léon)
# ..                                                 ...
# 220                                       Barry Lyndon
# 221                                    Rang De Basanti
# 222                                    Monstruos, S.A.
# 223                                 Las uvas de la ira
# 224                      El club de los poetas muertos
# 225                                   La linterna roja
# 226                                   El halcón maltés
# 227                                         Terminator
# 228                                             Gandhi
# 229                                        La doncella
# 230                                            El odio
# 231                                       Donnie Darko
# 232                                      Deseando amar
# 233                                     Las diabólicas
# 234                              Atrapado en el tiempo
# 235                                  Criadas y señoras
# 236                                      El mago de Oz
# 237                                            Tiburón
# 238                                Antes del atardecer
# 239                           Guardianes de la galaxia
# 240                                       París, Texas
# 241                            El castillo en el cielo
# 242                              Las noches de Cabiria
# 243  Piratas del Caribe: La maldición de la Perla N...
# 244                               La bella y la bestia
# 245                   Los mejores años de nuestra vida
# 246                                       El exorcista
# 247                                 Gangs of Wasseypur
# 248                                 Tres colores: Rojo
# 249                                    Tarde de perros
#
#                            Director Initial release Starts
# 0             Frank Darabont (dir.)            1994    9.2
# 1       Francis Ford Coppola (dir.)            1972    9.2
# 2       Francis Ford Coppola (dir.)            1974    9.0
# 3          Christopher Nolan (dir.)            2008    9.0
# 4               Sidney Lumet (dir.)            1957    8.9
# 5           Steven Spielberg (dir.)            1993    8.9
# 6              Peter Jackson (dir.)            2003    8.9
# 7          Quentin Tarantino (dir.)            1994    8.9
# 8              Anthony Russo (dir.)            2019    8.8
# 9               Sergio Leone (dir.)            1966    8.8
# 10             David Fincher (dir.)            1999    8.8
# 11             Peter Jackson (dir.)            2001    8.8
# 12           Robert Zemeckis (dir.)            1994    8.7
# 13            Irvin Kershner (dir.)            1980    8.7
# 14         Christopher Nolan (dir.)            2010    8.7
# 15             Peter Jackson (dir.)            2002    8.7
# 16              Milos Forman (dir.)            1975    8.7
# 17           Martin Scorsese (dir.)            1990    8.7
# 18            Lana Wachowski (dir.)            1999    8.6
# 19            Akira Kurosawa (dir.)            1954    8.6
# 20             David Fincher (dir.)            1995    8.6
# 21        Fernando Meirelles (dir.)            2002    8.6
# 22              George Lucas (dir.)            1977    8.6
# 23            Jonathan Demme (dir.)            1991    8.6
# 24               Frank Capra (dir.)            1946    8.6
# 25           Roberto Benigni (dir.)            1997    8.6
# 26            Hayao Miyazaki (dir.)            2001    8.5
# 27          Steven Spielberg (dir.)            1998    8.5
# 28              Bryan Singer (dir.)            1995    8.5
# 29                Luc Besson (dir.)            1994    8.5
# ..                              ...             ...    ...
# 220          Stanley Kubrick (dir.)            1975    8.0
# 221  Rakeysh Omprakash Mehra (dir.)            2006    8.0
# 222              Pete Docter (dir.)            2001    8.0
# 223                John Ford (dir.)            1940    8.0
# 224               Peter Weir (dir.)            1989    8.0
# 225              Yimou Zhang (dir.)            1991    8.0
# 226              John Huston (dir.)            1941    8.0
# 227            James Cameron (dir.)            1984    8.0
# 228     Richard Attenborough (dir.)            1982    8.0
# 229           Chan-wook Park (dir.)            2016    8.0
# 230        Mathieu Kassovitz (dir.)            1995    8.0
# 231            Richard Kelly (dir.)            2001    8.0
# 232             Kar-Wai Wong (dir.)            2000    8.0
# 233    Henri-Georges Clouzot (dir.)            1955    8.0
# 234             Harold Ramis (dir.)            1993    8.0
# 235              Tate Taylor (dir.)            2011    8.0
# 236           Victor Fleming (dir.)            1939    8.0
# 237         Steven Spielberg (dir.)            1975    8.0
# 238        Richard Linklater (dir.)            2004    8.0
# 239               James Gunn (dir.)            2014    8.0
# 240              Wim Wenders (dir.)            1984    8.0
# 241           Hayao Miyazaki (dir.)            1986    8.0
# 242         Federico Fellini (dir.)            1957    8.0
# 243           Gore Verbinski (dir.)            2003    8.0
# 244           Gary Trousdale (dir.)            1991    8.0
# 245            William Wyler (dir.)            1946    8.0
# 246         William Friedkin (dir.)            1973    8.0
# 247           Anurag Kashyap (dir.)            2012    8.0
# 248     Krzysztof Kieslowski (dir.)            1994    8.0
# 249             Sidney Lumet (dir.)            1975    8.0
#
# [250 rows x 4 columns]

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'
# Out:
# Enter the city:bilbao

# %%
# your code
print(url)
response = requests.get(url).json()

tiempo = {
    'ciudad' : city,
    'temperatura' : response['main']['temp'],
    'viento' : response['wind']['speed'],
    'descripcion' : response['weather'][0]['description'],
    'tiempo' : response['weather'][0]['main']
}

print(tiempo)
# Out:
# http://api.openweathermap.org/data/2.5/weather?q=bilbao&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric
# {'ciudad': 'bilbao', 'temperatura': 8.13, 'viento': 1.5, 'descripcion': 'light rain', 'tiempo': 'Rain'}

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
def limpia(t):
    t = re.sub(' ',' ',t)
    t = re.sub('\n\n','',t)
    return t.strip()

book_html = requests.get(url).text
soup_contenido = BeautifulSoup(book_html, "html.parser")
titulos = [titulo['alt'] for titulo in soup_contenido.find_all('img')]
precios = [precio.text.replace('Â', '') for precio in soup_contenido.find_all('p', class_="price_color")]
disponible = [stock.text for stock in soup_contenido.find_all('p', class_="instock")]

disponible = list(map(limpia, disponible))
libros = [ (titulos[libro], precios[libro], disponible[libro])  for libro in range(len(titulos))]

df = pd.DataFrame(libros, columns = ['Título', 'Precio', 'Diponibible'])
df.head()
# Out:
#                                   Título  Precio Diponibible
# 0                   A Light in the Attic  £51.77    In stock
# 1                     Tipping the Velvet  £53.74    In stock
# 2                             Soumission  £50.10    In stock
# 3                          Sharp Objects  £47.82    In stock
# 4  Sapiens: A Brief History of Humankind  £54.23    In stock
